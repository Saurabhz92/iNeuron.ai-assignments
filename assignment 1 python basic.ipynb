# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
#     answers =
#             *  =expression
#           'hello'=string value
#           -87.8  =integer value
#            -     =expression
#            /     =expression
#            +     =expression
#            6     =integer value

# %% [markdown]
# 2. What is the difference between string and variable?
#
# answer- String: String can be written in quotes such: "Saurabh", 'saurabh'
#
# Variable: It is the thing in which we can store data just like a container.
# eg a=10
# where a is a variable which can store integer data

# %% [markdown]
# 3. Describe three different data types.
#
# Answers = String: String can be written in quotes such: "saurabh", 'saurabh'
#
# Integer: integer can store only numerical values.
#
# Float: float can store only floating values such as 233.33, 22.2, etc.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
#
# answer=
#
# Expression is made up of values, containers, and mathematical operators (operands) e.g
#
#      a = 2 + 3     and expressions are used to evaluate the values or represent the result on the screen.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# answer = Expression is made up of values, containers, and mathematical operators (operands) and the statement is just like a command that a integer value 10 store in a spam word.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1
#
# Sol: it gives 23 as execution code ![rwqzbv2kv1JvX4oz8TpGxw2r2EgATo.png](attachment:rwqzbv2kv1JvX4oz8TpGxw2r2EgATo.png)

# %% [markdown]
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
#
# 'spam' * 3
#
# sol: it will be the same
# ![rwqzbv2kv1JvX4oz8TpGxw2r2EgATo.png](attachment:rwqzbv2kv1JvX4oz8TpGxw2r2EgATo.png)

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Answer: because we can't start giving variable an integer name. if we, we should begin with, a string-like alphabet name then write a integer then its. e100 or eggs100 is valid

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# answer:  int(), float(),str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
#
# 'I have eaten' + 99 + 'burritos'
#
# sol:  because 99 is an integer it cannot be concatenated with strings, if we have to concatenate it we need to do typecasting.
